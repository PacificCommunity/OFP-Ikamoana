# %%
import sys
sys.path.append('./../../')

# %%
import ikamoana.fisherieseffort.fisherieseffort as fe
import numpy as np

# %%
filepath = "./../../data/SEAPODYM_data/run-test/data/fisheries/skj_fisheries_data_2021_Nov17.txt"

# %% [markdown]
# ---
# ## Fishery Effort Time Coords

# %%
fisheries_df = fe.readFile(filepath)
fisheries_dict = fe.separateFisheries(fisheries_df)
fisheries_dict[9] = fe.predictEffort(fisheries_dict[9])

# Speed up the test :

fisheries_dict.pop(2)
fisheries_dict.pop(3)
fisheries_dict.pop(4)
fisheries_dict.pop(5)
fisheries_dict.pop(6)
fisheries_dict.pop(7)
fisheries_dict.pop(8)
fisheries_dict.pop(9)
fisheries_dict.pop(10)
fisheries_dict.pop(12)
fisheries_dict.pop(13)
fisheries_dict.pop(15)

for i in fisheries_dict.keys()  :
    print("[%d]"%(i),end="  ")
print()
for i in fisheries_dict  :
    print(np.unique(fisheries_dict[i].res),end="  ")
print()

fisheries_dict = fe.rescaleFisheries(fisheries_dict, 0.5)
fisheries_groub_by_dict = fe.groupByFisheries(fisheries_dict)
fe_ds, _ = fe.fisheriesToDataSet(fisheries_groub_by_dict)
# Out:
# [1]
# [1]

# %%
fe_ds
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 852, lat: 52, lon: 210)
# Coordinates:
#   * time     (time) datetime64[ns] 1950-01-15 1950-02-15 ... 2020-12-15
#   * lat      (lat) float64 21.0 21.5 22.0 22.5 23.0 ... 44.5 45.0 45.5 46.0 46.5
#   * lon      (lon) float64 116.5 117.0 117.5 118.0 ... 227.5 228.0 229.5 230.0
# Data variables:
#     1        (time, lat, lon) float64 nan nan nan nan nan ... nan nan nan nan
# Attributes:
#     Type:     E

# %%
fe.normalizeCoords(fe_ds, deltaT=30, space_reso=0.5)
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 852, lat: 52, lon: 228)
# Coordinates:
#   * time     (time) datetime64[ns] 1950-01-01 1950-02-01 ... 2020-12-01
#   * lat      (lat) float64 21.0 21.5 22.0 22.5 23.0 ... 44.5 45.0 45.5 46.0 46.5
#   * lon      (lon) float64 116.5 117.0 117.5 118.0 ... 228.5 229.0 229.5 230.0
# Data variables:
#     1        (time, lat, lon) float64 nan nan nan nan nan ... nan nan nan nan
# Attributes:
#     Type:     E

# %%
fe.normalizeCoords(fe_ds, deltaT=60)
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 433, lat: 52, lon: 210)
# Coordinates:
#   * time     (time) datetime64[ns] 1950-01-15 1950-03-16 ... 2020-12-15
#   * lat      (lat) float64 21.0 21.5 22.0 22.5 23.0 ... 44.5 45.0 45.5 46.0 46.5
#   * lon      (lon) float64 116.5 117.0 117.5 118.0 ... 227.5 228.0 229.5 230.0
# Data variables:
#     1        (time, lat, lon) float64 nan nan nan nan nan ... nan nan nan nan
# Attributes:
#     Type:     E

# %%
fe.normalizeCoords(fe_ds, space_reso=1)
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 852, lat: 27, lon: 115)
# Coordinates:
#   * time     (time) datetime64[ns] 1950-01-15 1950-02-15 ... 2020-12-15
#   * lat      (lat) float64 21.0 22.0 23.0 24.0 25.0 ... 43.0 44.0 45.0 46.0 46.5
#   * lon      (lon) float64 116.5 117.5 118.5 119.5 ... 227.5 228.5 229.5 230.0
# Data variables:
#     1        (time, lat, lon) float64 nan nan nan nan nan ... nan nan nan nan
# Attributes:
#     Type:     E
