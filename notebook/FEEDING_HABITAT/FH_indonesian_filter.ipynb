# %%
import sys
sys.path.append('./../../')

# %%
import ikamoana
import numpy as np
import pandas as pd
import xarray as xr

# %%
xml_filepath="./../../data/SEAPODYM_data/run-test/skj_interim_CL_2018_testopt.xml"
fh = ikamoana.feedinghabitat.FeedingHabitat(xml_filepath)

# %%
fh.data_structure.variables_dictionary['sst'][0].plot()

# %%
fh.indonesianFilter()

# %%
fh.data_structure.variables_dictionary['sst'][0].plot()
