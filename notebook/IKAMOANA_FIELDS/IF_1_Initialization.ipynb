# %%
import sys
sys.path.append('./../../')

import ikamoana

ikamoana_filepath = "./../../data/ikamoana_config/IkaSim_Example.xml"
seapodym_filepath = "./../../data/SEAPODYM_data/run-test/skj_CLT_e5_3_est.xml"
# seapodym_filepath = "./../../data/skj_CLT_e5_3_est.xml"

# %%
ika_fields = ikamoana.IkamoanaFields(
    ikamoana_filepath, seapodym_filepath)
ika_fields.__dict__.keys()
# Out:
# dict_keys(['feeding_habitat', 'ikamoana_fields_structure', 'feeding_habitat_structure'])

# %%
ika_fields.computeFeedingHabitat(0)
ika_fields.feeding_habitat
# Out:
# <xarray.DataArray 'Feeding_Habitat_Cohort_0' (time: 384, lat: 60, lon: 101)>
# array([[[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
# ...
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
# ...

# %%
ika_fields.computeEvolvingFeedingHabitat(0,1)
ika_fields.feeding_habitat
# Out:
# <xarray.DataArray 'Feeding_Habitat_Cohort_0_to_1' (time: 2, lat: 60, lon: 101)>
# array([[[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]]])
# Coordinates:
#   * lat      (lat) float32 -53.5 -51.5 -49.5 -47.5 -45.5 ... 58.5 60.5 62.5 64.5
#   * time     (time) datetime64[ns] 1979-01-15 1979-02-14
#   * lon      (lon) float32 89.5 91.5 93.5 95.5 97.5 ... 283.5 285.5 287.5 289.5
#     cohorts  (time) int64 0 1
# Attributes:
# ...
