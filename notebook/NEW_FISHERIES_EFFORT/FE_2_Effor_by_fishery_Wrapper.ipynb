# %%
import sys
sys.path.append('./../../')

import ikamoana
import xml.etree.ElementTree as ET
import numpy as np
import pandas as pd
import xarray as xr

filepath_ika_config = "./../../data/ikamoana_config/IkaSim_Example.xml"
filepath_effort = "./../../data//SEAPODYM_data/run-test/data/fisheries/skj_fisheries_data_2021_Nov17.txt"

# %%
ika = ikamoana.IkamoanaFields(filepath_ika_config)
ikamoana.fisherieseffort.NEWfisherieseffort.effortByFishery(
    filepath=filepath_effort,
    space_reso=ika.feeding_habitat_structure.data_structure.parameters_dictionary['space_reso'],
    time_reso=ika.feeding_habitat_structure.data_structure.parameters_dictionary['deltaT'],
    coords=ika.feeding_habitat_structure.data_structure.coords,
    skiprows=0,
    selected_fisheries=['1','15']
)
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 849, lat: 34, lon: 77)
# Coordinates:
#   * time     (time) datetime64[ns] 1950-01-15 1950-02-15 ... 2020-10-15
#   * lat      (lat) float64 -19.5 -17.5 -15.5 -13.5 -11.5 ... 40.5 42.5 44.5 46.5
#   * lon      (lon) float64 115.5 117.5 119.5 121.5 ... 261.5 263.5 265.5 267.5
# Data variables:
#     1        (time, lat, lon) float64 nan nan nan nan nan ... nan nan nan nan
#     15       (time, lat, lon) float64 nan nan nan nan nan ... nan nan nan nan
