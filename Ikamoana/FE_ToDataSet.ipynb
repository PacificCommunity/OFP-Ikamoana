# %%
import ikamoana.fisheries_effort.fisheries_effort as fe
import numpy as np
import pandas as pd

# %%
## Non unique value in the fisheries_effort file will lead to error in DataSet transformation

filepath = "./data/fisheries_effort/fisheries_data_2021_Nov8.txt"

# %% [raw]
# fe.readFile(filepath, header_position=0, columns_name=["fishery","year","month","day","gear","latitude","longitude","resolution","Effort","Catch"])

# %%
fisheries_df = fe.readFile(filepath, header_position=0, columns_name=None)
fisheries_dict = fe.separateFisheries(fisheries_df)
fisheries_dict[1]
# Out:
#         f    yr  mm  dd gr   lat    lon  res    E      C
# 0       1  1950   1  15  P  46.5  150.5    1  1.0  0.047
# 1       1  1950   1  15  P  34.5  136.5    1  0.0  0.000
# 2       1  1950   1  15  P  34.5  138.5    1  0.0  0.000
# 3       1  1950   1  15  P  34.5  139.5    1  9.0  0.000
# 4       1  1950   1  15  P  33.5  133.5    1  0.0  0.000
# ...    ..   ...  ..  .. ..   ...    ...  ...  ...    ...
# 192946  1  2020  12  15  P  25.5  130.5    1  0.0  2.118
# 192947  1  2020  12  15  P  25.5  131.5    1  0.0  2.118
# 192948  1  2020  12  15  P  25.5  132.5    1  0.0  2.118
# 192949  1  2020  12  15  P  25.5  133.5    1  0.0  2.118
# 192950  1  2020  12  15  P  25.5  134.5    1  0.0  2.118
#
# [192951 rows x 10 columns]

# %%
## The coordinates are not continuous. There is holes in series.

# for k, i in fisheries_dict.items():
#     array = fe.toDataArray(i)
#     E = array.set_index(["time","lat","lon"]).to_xarray()["E"]
#     print(E.time.data[0])
#     print(E.time.data[-1])
#     print(E.time.data.size)
#     print("#############")

# %%
tmp = fe.toDataSet(fisheries_dict[1])
tmp
# Out:
# <xarray.Dataset>
# Dimensions:      (time: 852, lat: 26, lon: 105)
# Coordinates:
#   * time         (time) datetime64[ns] 1950-01-15 1950-02-15 ... 2020-12-15
#   * lat          (lat) float64 21.5 22.5 23.5 24.5 25.5 ... 43.5 44.5 45.5 46.5
#   * lon          (lon) float64 116.5 117.5 118.5 119.5 ... 223.5 227.5 229.5
# Data variables:
#     Fishery_1_E  (time, lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     Fishery_1_C  (time, lat, lon) float64 nan nan nan nan ... nan nan nan nan
# Attributes:
#     Fishery_1_Gear:  ['P']
