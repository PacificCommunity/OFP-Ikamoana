# %%
import sys
sys.path.append('./../../')

# %%
import ikamoana.fisherieseffort.fisherieseffort as fe
import ikamoana.feedinghabitat.feedinghabitat as fh
import xarray as xr
import pandas as pd
import numpy as np
from typing import Union

# %%
filepath = "./../../data/fisheries_effort/skj_fisheries_data_2021_Nov17.txt"

# %% [markdown]
# ---
# ## Fishery Effort Time Coords

# %%
fisheries_df = fe.readFile(filepath, columns_name=None)
fisheries_dict = fe.separateFisheries(fisheries_df)
fisheries_dict[9] = fe.predictEffort(fisheries_dict[9])

# Speed up the test :
fisheries_dict.pop(8)

for i in fisheries_dict.keys()  :
    print("[%d]"%(i),end="  ")
print()
for i in fisheries_dict  :
    print(np.unique(fisheries_dict[i].res),end="  ")
print()

fisheries_dict = fe.rescaleFisheries(fisheries_dict)
fisheries_groub_by_dict = fe.groupByFisheries(fisheries_dict)
fe_ds, _ = fe.fisheriesToDataSet(fisheries_groub_by_dict)

# %%
fe_ds[[1,2]]
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 858, lat: 95, lon: 180)
# Coordinates:
#   * time     (time) datetime64[ns] 1950-01-15 1950-02-15 ... 2021-06-15
#   * lat      (lat) float64 -49.5 -46.5 -45.5 -44.5 -43.5 ... 46.5 47.5 48.5 49.5
#   * lon      (lon) float64 0.5 110.5 111.5 112.5 ... 285.5 286.5 287.5 288.5
# Data variables:
#     1        (time, lat, lon) float64 nan nan nan nan nan ... nan nan nan nan
#     2        (time, lat, lon) float64 nan nan nan nan nan ... nan nan nan nan
# Attributes:
#     Type:     E

# %%
fe.normalizeCoords(fe_ds[[1,2]], deltaT=60)
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 436, lat: 95, lon: 180)
# Coordinates:
#   * time     (time) datetime64[ns] 1950-01-15 1950-03-16 ... 2021-06-15
#   * lat      (lat) float64 -49.5 -46.5 -45.5 -44.5 -43.5 ... 46.5 47.5 48.5 49.5
#   * lon      (lon) float64 0.5 110.5 111.5 112.5 ... 285.5 286.5 287.5 288.5
# Data variables:
#     1        (time, lat, lon) float64 nan nan nan nan nan ... nan nan nan nan
#     2        (time, lat, lon) float64 nan nan nan nan nan ... nan nan nan nan
# Attributes:
#     Type:     E

# %%
fe.normalizeCoords(fe_ds[[1,2]], space_reso=1)
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 858, lat: 100, lon: 289)
# Coordinates:
#   * time     (time) datetime64[ns] 1950-01-15 1950-02-15 ... 2021-06-15
#   * lat      (lat) float64 -49.5 -48.5 -47.5 -46.5 -45.5 ... 46.5 47.5 48.5 49.5
#   * lon      (lon) float64 0.5 1.5 2.5 3.5 4.5 ... 284.5 285.5 286.5 287.5 288.5
# Data variables:
#     1        (time, lat, lon) float64 nan nan nan nan nan ... nan nan nan nan
#     2        (time, lat, lon) float64 nan nan nan nan nan ... nan nan nan nan
# Attributes:
#     Type:     E
