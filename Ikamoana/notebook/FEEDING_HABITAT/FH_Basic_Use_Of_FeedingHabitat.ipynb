# %%
import sys
sys.path.append('./../../')

# %%
import numpy as np
import ikamoana

# %%
fh = ikamoana.feedinghabitat.FeedingHabitat(
    "./../../data/SEAPODYM_data/run-test/skj_interim_CL_2018_testopt.xml",
    )

# %%
# # Building climatic oxygen model
# for i in ["oxygen_L1", "oxygen_L2", "oxygen_L3"] :
#     data = fh.data_structure.variables_dictionary[i]
#     data = data.sel(time=data.time.data[0:12])
#     fh.data_structure.variables_dictionary[i] = data

# fh.data_structure.partial_oxygen_time_axis = True

# %%
fh.data_structure
# Out:
# # ------------------------------ #
# # Summary of this data structure #
# # ------------------------------ #
#
# Root directory is :
# 	./../../data/SEAPODYM_data/run-test/data/run-interim_2x30d_po/
# Output directory is :
# 	./../../data/SEAPODYM_data/run-test/data/run-interim_2x30d_po/output/
# Time resolution is (in days) : 30.0
# Space resolution is (in degrees) : 2.0
#
#
# # -------------------------------SPECIES----------------------------- #
#
# The short name of the species is skj.
# There is(are) 3 life stage(s) considered in the model which is(are) : ['larvae', 'juvenile', 'adult']
# 	- There is(are) 1	cohort(s) in life stage larvae.
# 	- There is(are) 2	cohort(s) in life stage juvenile.
# 	- There is(are) 34	cohort(s) in life stage adult.
#
# Final age (in day) of each cohort is :
# [  30.   60.   90.  120.  150.  180.  210.  240.  270.  300.  330.  360.
#   390.  420.  450.  480.  510.  540.  570.  600.  630.  660.  690.  720.
#   750.  780.  810.  840.  870.  900.  930.  960.  990. 1020. 1050. 1080.
#  1680.]
#
# Mean length for each cohort is :
# [ 3.    4.5   7.52 11.65 16.91 21.83 26.43 30.72 34.73 38.49 41.99 45.27
#  48.33 51.19 53.86 56.36 58.7  60.88 62.92 64.83 66.61 68.27 69.83 71.28
#  72.64 73.91 75.1  76.21 77.25 78.22 79.12 79.97 80.76 81.5  82.19 82.83
#  87.96]
#
# Mean weight for each cohort is :
# [ 0.0003   0.00109  0.00571  0.023    0.08     0.18     0.32     0.53
#   0.78     1.09     1.44     1.84     2.27     2.73     3.21     3.72
#   4.23     4.76     5.3      5.83     6.36     6.89     7.4      7.91
#   8.41     8.89     9.36     9.81    10.25    10.66    11.07    11.45
#  11.82    12.17    12.51    12.83    15.56   ]
#
#
# # -----------------------------PARAMETERS---------------------------- #
#
# The parameters used are the following :
# 	- eF_list     :  [8.657, 0.256, 7.243, 5.17, 7.152, 0.306]
# 	- sigma_0     :  1.269
# 	- sigma_K     :  3.0
# 	- T_star_1    :  30.185
# 	- T_star_K    :  23.725
# 	- bT          :  2.294
# 	- gamma       :  0.0001
# 	- o_star      :  2.474
# 	- deltaT      :  30.0
# 	- space_reso  :  2.0
#
# Reminder :
#         - Forage        -> eF
#         - Temperature   -> sigma, T* and bT
#         - Oxygen        -> gamma and O*
#
# # ------------------------------FIELDS------------------------------- #
#
# WARNING : Fields must start on the same date !
#
# Fields are grouped by coordinates :
#
# #	#	#	#	#
#
# Group : ('oxygen_L1', 'oxygen_L2', 'oxygen_L3', 'temperature_L1', 'temperature_L2', 'temperature_L3', 'sst', 'vld', 'days_length')
# Their coordinates are :
# Coordinates:
#   * time     (time) datetime64[ns] 1979-01-15 1979-02-14 ... 2010-12-16
#   * lat      (lat) float32 64.5 62.5 60.5 58.5 56.5 ... -47.5 -49.5 -51.5 -53.5
#   * lon      (lon) float32 89.5 91.5 93.5 95.5 97.5 ... 283.5 285.5 287.5 289.5
#
# #	#	#	#	#
#
# Group : ('forage_epi', 'forage_umeso', 'forage_mumeso', 'forage_lmeso', 'forage_mlmeso', 'forage_hmlmeso')
# Their coordinates are :
# Coordinates:
#   * time     (time) datetime64[ns] 1979-01-15 1979-02-15 ... 2010-12-15
#   * lat      (lat) float32 64.5 62.5 60.5 58.5 56.5 ... -47.5 -49.5 -51.5 -53.5
#   * lon      (lon) float32 89.5 91.5 93.5 95.5 97.5 ... 283.5 285.5 287.5 289.5
#
# #	#	#	#	#
#
# Day Length is calculated using the main coordinates which arebased on temperature (L1) field.
#
# #	#	#	#	#
#
# TIPS : The user can use equalCoords() or compareDims() functionsto compare Coordinates.
#
# # ------------------------------------------------------------------- #

# %% [markdown]
# ### Find cohort by length or weight

# %%
_ = fh.data_structure.findCohortByLength(10, True)
_ = fh.data_structure.findCohortByWeight(10, True)
# Out:
# The cohort with the length closest to 10.000000 is cohort number 3 whose length is 11.650000
# The cohort with the weight closest to 10.000000 is cohort number 27 whose weight is 9.810000

# %% [markdown]
# ### A simple test

# %%
fh.computeFeedingHabitat(0)
# Out:
# <xarray.Dataset>
# Dimensions:                   (lon: 101, lat: 60, time: 384)
# Coordinates:
#   * lon                       (lon) float32 89.5 91.5 93.5 ... 285.5 287.5 289.5
#   * lat                       (lat) float32 64.5 62.5 60.5 ... -49.5 -51.5 -53.5
#   * time                      (time) datetime64[ns] 1979-01-15 ... 2010-12-16
# Data variables:
#     Feeding_Habitat_Cohort_0  (time, lat, lon) float32 nan nan nan ... nan nan
# Attributes: (12/16)
#     time_start:  None
#     time_end:    None
#     lat_min:     None
#     lat_max:     None
#     lon_min:     None
#     lon_max:     None
#     ...          ...
#     T_star_K:    23.725
#     bT:          2.294
#     gamma:       0.0001
#     o_star:      2.474
#     deltaT:      30.0
#     space_reso:  2.0

# %%
fh.computeFeedingHabitat([0,1,2,3])
# Out:
# <xarray.Dataset>
# Dimensions:                   (lon: 101, lat: 60, time: 384)
# Coordinates:
#   * lon                       (lon) float32 89.5 91.5 93.5 ... 285.5 287.5 289.5
#   * lat                       (lat) float32 64.5 62.5 60.5 ... -49.5 -51.5 -53.5
#   * time                      (time) datetime64[ns] 1979-01-15 ... 2010-12-16
# Data variables:
#     Feeding_Habitat_Cohort_0  (time, lat, lon) float32 nan nan nan ... nan nan
#     Feeding_Habitat_Cohort_1  (time, lat, lon) float32 nan nan nan ... nan nan
#     Feeding_Habitat_Cohort_2  (time, lat, lon) float32 nan nan nan ... nan nan
#     Feeding_Habitat_Cohort_3  (time, lat, lon) float32 nan nan nan ... nan nan
# Attributes: (12/16)
#     time_start:  None
#     time_end:    None
#     lat_min:     None
#     lat_max:     None
#     lon_min:     None
#     lon_max:     None
#     ...          ...
#     T_star_K:    23.725
#     bT:          2.294
#     gamma:       0.0001
#     o_star:      2.474
#     deltaT:      30.0
#     space_reso:  2.0

# %% [markdown]
# ### Test equals values

# %%
fh.computeFeedingHabitat(cohorts=0,
    time_start=10, time_end=None,
    lat_min=None, lat_max=20,
    lon_min=None, lon_max=None)
# Out:
# <xarray.Dataset>
# Dimensions:                   (lon: 101, lat: 21, time: 374)
# Coordinates:
#   * lon                       (lon) float32 89.5 91.5 93.5 ... 285.5 287.5 289.5
#   * lat                       (lat) float32 64.5 62.5 60.5 ... 28.5 26.5 24.5
#   * time                      (time) datetime64[ns] 1979-11-15 ... 2010-12-16
# Data variables:
#     Feeding_Habitat_Cohort_0  (time, lat, lon) float32 nan nan nan ... nan nan
# Attributes: (12/16)
#     time_start:  10
#     time_end:    None
#     lat_min:     None
#     lat_max:     20
#     lon_min:     None
#     lon_max:     None
#     ...          ...
#     T_star_K:    23.725
#     bT:          2.294
#     gamma:       0.0001
#     o_star:      2.474
#     deltaT:      30.0
#     space_reso:  2.0

# %% [markdown]
# ### Test aux bornes

# %%
fh.computeFeedingHabitat(
    cohorts = np.arange(0,fh.data_structure.cohorts_number),
    time_start=0, time_end=383,
    lat_min=0, lat_max=59,
    lon_min=0, lon_max=100,
    verbose=True)
# Out:
# Computing Feeding Habitat for cohort 0.
# Computing Feeding Habitat for cohort 1.
# Computing Feeding Habitat for cohort 2.
# Computing Feeding Habitat for cohort 3.
# Computing Feeding Habitat for cohort 4.
# Computing Feeding Habitat for cohort 5.
# Computing Feeding Habitat for cohort 6.
# Computing Feeding Habitat for cohort 7.
# Computing Feeding Habitat for cohort 8.
# Computing Feeding Habitat for cohort 9.
# Computing Feeding Habitat for cohort 10.
# Computing Feeding Habitat for cohort 11.
# Computing Feeding Habitat for cohort 12.
# Computing Feeding Habitat for cohort 13.
# Computing Feeding Habitat for cohort 14.
# Computing Feeding Habitat for cohort 15.
# Computing Feeding Habitat for cohort 16.
# Computing Feeding Habitat for cohort 17.
# Computing Feeding Habitat for cohort 18.
# Computing Feeding Habitat for cohort 19.
# Computing Feeding Habitat for cohort 20.
# Computing Feeding Habitat for cohort 21.
# Computing Feeding Habitat for cohort 22.
# Computing Feeding Habitat for cohort 23.
# Computing Feeding Habitat for cohort 24.
# Computing Feeding Habitat for cohort 25.
# Computing Feeding Habitat for cohort 26.
# Computing Feeding Habitat for cohort 27.
# Computing Feeding Habitat for cohort 28.
# Computing Feeding Habitat for cohort 29.
# Computing Feeding Habitat for cohort 30.
# Computing Feeding Habitat for cohort 31.
# Computing Feeding Habitat for cohort 32.
# Computing Feeding Habitat for cohort 33.
# Computing Feeding Habitat for cohort 34.
# Computing Feeding Habitat for cohort 35.
# Computing Feeding Habitat for cohort 36.
# <xarray.Dataset>
# Dimensions:                    (lon: 101, lat: 60, time: 384)
# Coordinates:
#   * lon                        (lon) float32 89.5 91.5 93.5 ... 287.5 289.5
#   * lat                        (lat) float32 64.5 62.5 60.5 ... -51.5 -53.5
#   * time                       (time) datetime64[ns] 1979-01-15 ... 2010-12-16
# Data variables: (12/37)
#     Feeding_Habitat_Cohort_0   (time, lat, lon) float32 nan nan nan ... nan nan
#     Feeding_Habitat_Cohort_1   (time, lat, lon) float32 nan nan nan ... nan nan
#     Feeding_Habitat_Cohort_2   (time, lat, lon) float32 nan nan nan ... nan nan
#     Feeding_Habitat_Cohort_3   (time, lat, lon) float32 nan nan nan ... nan nan
#     Feeding_Habitat_Cohort_4   (time, lat, lon) float32 nan nan nan ... nan nan
#     Feeding_Habitat_Cohort_5   (time, lat, lon) float32 nan nan nan ... nan nan
#     ...                         ...
#     Feeding_Habitat_Cohort_31  (time, lat, lon) float32 nan nan nan ... nan nan
#     Feeding_Habitat_Cohort_32  (time, lat, lon) float32 nan nan nan ... nan nan
#     Feeding_Habitat_Cohort_33  (time, lat, lon) float32 nan nan nan ... nan nan
#     Feeding_Habitat_Cohort_34  (time, lat, lon) float32 nan nan nan ... nan nan
#     Feeding_Habitat_Cohort_35  (time, lat, lon) float32 nan nan nan ... nan nan
#     Feeding_Habitat_Cohort_36  (time, lat, lon) float32 nan nan nan ... nan nan
# Attributes: (12/16)
#     time_start:  0
#     time_end:    383
#     lat_min:     0
#     lat_max:     59
#     lon_min:     0
#     lon_max:     100
#     ...          ...
#     T_star_K:    23.725
#     bT:          2.294
#     gamma:       0.0001
#     o_star:      2.474
#     deltaT:      30.0
#     space_reso:  2.0
