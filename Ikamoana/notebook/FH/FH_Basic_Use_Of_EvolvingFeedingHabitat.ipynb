# %%
import sys
sys.path.append('./../../')

# %%
import numpy as np
import ikamoana

# %%
fh = ikamoana.feedinghabitat.FeedingHabitat(
    xml_filepath="./../../data/feeding_habitat_data/po_2x30_historical_interim/skj_po_interim_2deg_configuration_file.xml")

# %%
# # Building climatic oxygen model
# for i in ["oxygen_L1", "oxygen_L2", "oxygen_L3"] :
#     data = fh.data_structure.variables_dictionary[i]
#     data = data.sel(time=data.time.data[0:12])
#     fh.data_structure.variables_dictionary[i] = data

# fh.data_structure.partial_oxygen_time_axis = True

# %%
fh.data_structure
# Out:
# # ------------------------------ #
# # Summary of this data structure #
# # ------------------------------ #
#
# Root directory is :
# 	/home/ash/Documents/GitHub_Repositories/OFP-Ikamoana/Ikamoana/data/feeding_habitat_data/po_2x30_historical_interim/
# Output directory is :
# 	/home/ash/Documents/GitHub_Repositories/OFP-Ikamoana/Ikamoana/data/feeding_habitat_data/po_2x30_historical_interim/output/
# Time resolution is (in days) : 30.0
# Space resolution is (in degrees) : 2.0
#
#
# # -------------------------------SPECIES----------------------------- #
#
# The short name of the species is skj.
# There is(are) 3 life stage(s) considered in the model which is(are) : ['larvae', 'juvenile', 'adult']
# 	- There is(are) 1	cohort(s) in life stage larvae.
# 	- There is(are) 2	cohort(s) in life stage juvenile.
# 	- There is(are) 34	cohort(s) in life stage adult.
#
# Final age (in day) of each cohort is :
# [  30.   60.   90.  120.  150.  180.  210.  240.  270.  300.  330.  360.
# ...

# %% [markdown]
# ### Find cohort by length or weight

# %%
_ = fh.data_structure.findCohortByLength(10, True)
_ = fh.data_structure.findCohortByWeight(10, True)
# Out:
# The cohort with the length closest to 10.000000 is cohort number 3 whose length is 11.650000
# The cohort with the weight closest to 10.000000 is cohort number 27 whose weight is 9.810000

# %% [markdown]
# ### A simple test

# %%
fh.computeEvolvingFeedingHabitat()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# /tmp/ipykernel_11586/171178348.py in <module>
# ----> 1 fh.computeEvolvingFeedingHabitat()
#
# ~/Documents/GitHub_Repositories/OFP-Ikamoana/Ikamoana/notebook/FH/./../../ikamoana/feedinghabitat/feedinghabitat.py in computeEvolvingFeedingHabitat(self, cohort_start, cohort_end, time_start, time_end, lat_min, lat_max, lon_min, lon_max, control_arg, verbose)
#     707         final_array = []
#     708         #for i in range(cohort_array.size) :
# --> 709         for i in range(max_size) :
#     710             # Oldest cohort with many time steps
#     711             if (cohort_array[i:].size == 1) and (time_array[i:].size > 1) :
#
# UnboundLocalError: local variable 'max_size' referenced before assignment

# %%
fh.computeEvolvingFeedingHabitat(0,10)
# Out:
# <xarray.DataArray 'Feeding_Habitat_Cohort_0_to_10' (time: 11, lat: 60, lon: 101)>
# array([[[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
# ...
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
# ...

# %% [markdown]
# ### Test equals values

# %%
fh.computeEvolvingFeedingHabitat(
    cohort_start=0, cohort_end=10,
    time_start=10, time_end=None,
    lat_min=None, lat_max=20,
    lon_min=None, lon_max=None)
# Out:
# <xarray.DataArray 'Feeding_Habitat_Cohort_0_to_10' (time: 11, lat: 21, lon: 101)>
# array([[[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
# ...
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
# ...

# %% [markdown]
# ### Test aux bornes

# %%
fh.computeEvolvingFeedingHabitat(
    0,36,
    time_start=0, time_end=383,
    lat_min=0, lat_max=59,
    lon_min=0, lon_max=100,
    verbose=True)
# Out:
# <xarray.DataArray 'Feeding_Habitat_Cohort_0_to_36' (time: 384, lat: 60, lon: 101)>
# array([[[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
# ...
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
# ...

# %% [markdown]
# ---
# # Test : time limites but no cohort_end

# %%
fh.computeEvolvingFeedingHabitat(
    10,None,
    time_start=10, time_end=20)
# Out:
# <xarray.DataArray 'Feeding_Habitat_Cohort_10_to_36' (time: 11, lat: 60, lon: 101)>
# array([[[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
# ...
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
# ...
