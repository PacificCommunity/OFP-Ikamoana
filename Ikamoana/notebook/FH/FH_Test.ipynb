# %%
import sys
sys.path.append('./../../')

# %%
import ikamoana
import numpy as np

# %%
filepath = "./../../data/feeding_habitat_data/po_2x30_historical_interim/skj_po_interim_2deg_configuration_file.xml"

# %%
fh = ikamoana.feedinghabitat.FeedingHabitat(filepath)

# %%
tmp = {
    "cohorts":0,
    "lat_min":10,
    "lat_max":20,
    "lon_min":10,
    "lon_max":20,
}

# %%
fh.computeFeedingHabitat(**tmp)
# Out:
# <xarray.Dataset>
# Dimensions:                   (lon: 11, lat: 11, time: 384)
# Coordinates:
#   * lon                       (lon) float32 109.5 111.5 113.5 ... 127.5 129.5
#   * lat                       (lat) float32 44.5 42.5 40.5 ... 28.5 26.5 24.5
#   * time                      (time) datetime64[ns] 1979-01-15T12:00:00 ... 2...
# Data variables:
#     Feeding_Habitat_Cohort_0  (time, lat, lon) float32 nan nan ... 0.0006903
# Attributes: (12/16)
#     time_start:  None
#     time_end:    None
#     lat_min:     10
#     lat_max:     20
#     lon_min:     10
#     lon_max:     20
#     ...          ...
#     T_star_K:    26.04960048814059
#     bT:          2.83057972721579
#     gamma:       0.0001000000005808978
#     o_star:      3.764163854561827
#     deltaT:      30.0
#     space_reso:  2.0

# %%
tmp = {
    "lat_min":10,
    "lat_max":20,
    "lon_min":10,
    "lon_max":20,
}

# %%
fh.computeEvolvingFeedingHabitat(**tmp)
# Out:
# <xarray.DataArray 'Feeding_Habitat_Cohort_0_to_36' (time: 384, lat: 11, lon: 11)>
# array([[[          nan,           nan,           nan, ...,
#                    nan,           nan,           nan],
#         [          nan,           nan,           nan, ...,
#                    nan,           nan,           nan],
#         [          nan,           nan,           nan, ...,
#                    nan,           nan,           nan],
#         ...,
#         [          nan,           nan,           nan, ...,
#          1.9347668e-04, 1.7070770e-04, 1.3738871e-04],
#         [          nan,           nan,           nan, ...,
#          1.4120340e-04, 3.8999319e-04, 4.4709444e-04],
#         [          nan,           nan,           nan, ...,
#          2.4765730e-04, 3.3819675e-04, 6.7907572e-04]],
#
#        [[          nan,           nan,           nan, ...,
#                    nan,           nan,           nan],
#         [          nan,           nan,           nan, ...,
# ...
