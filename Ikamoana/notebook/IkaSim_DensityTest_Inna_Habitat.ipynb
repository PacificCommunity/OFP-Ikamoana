# %%
import sys
sys.path.append('./../')

# %%
import numpy as np
import ikamoana as ika
import xarray as xr

# %%
import xml.etree.ElementTree as ET
tree = ET.parse('./IkaSim_DensityTest.xml')
root = tree.getroot()

# %%
# ika_file = 'C:/Users/joes/Dropbox/SPC_2020/OFP-Ikamoana/Ikamoana/ikamoana/IkaSim_DensityTest.xml'
ika_file = './IkaSim_DensityTest.xml'

IkaTest = ika.ikamoana.IkaSim(ika_file)

# %%
IkaTest.forcing_gen.feeding_habitat_structure.correctEpiTempWithVld()
# Out:
# Warning : This function (correctEpiTempWithVld) was only tested for Skipjack.
#  It will also add +1 to sigma_min. Cf. function documentation for more details.

# %%
# IkaTest.generateForcingNEW()
IkaTest.generateForcingNEW(
    from_habitat=xr.open_dataarray('./../data/Inna/Modified_skj_cohort_habitat_20080115-20080515_20080115.nc')
)
print(IkaTest.forcing['K'].sum().data)
print(IkaTest.forcing['dK_dx'].sum().data)
print(IkaTest.forcing['dK_dy'].sum().data)
# Out:
# 186955870.0
# -0.028697833
# 0.5759071

# %%
IkaTest.forcing['H'][3].plot()

# %%
IkaTest.generateForcingNEW()
# IkaTest.generateForcingNEW(
#     from_habitat=xr.open_dataarray('./../data/Inna/Modified_skj_cohort_habitat_20080115-20080515_20080115.nc')
# )
print(IkaTest.forcing['K'].sum().data)
print(IkaTest.forcing['dK_dx'].sum().data)
print(IkaTest.forcing['dK_dy'].sum().data)
# Out:
# 182479100.0
# 2.2612607
# 1.937542

# %%
IkaTest.forcing['H'][3].plot()

# %%
IkaTest.forcing['K'][3].plot()

# %%
IkaTest.forcing['dK_dx'][3].plot()

# %%
IkaTest.forcing['dK_dy'][3].plot()

# %%
IkaTest.createFieldSet()

# %%
#Create N particles using the default start field distribution already loaded into the fieldset(start=None)
N = 50000
IkaTest.initialiseFishParticles(start=None,n_fish=N, pclass=ika.ikafish.ikafish.IkaFish)

# %%
#Run the behavioural kernels for two months
IkaTest.runKernels(T=86400*10)
# Out:
# WARNING: u1 declared in multiple Kernels
# WARNING: v1 declared in multiple Kernels
# WARNING: lon1 declared in multiple Kernels
# WARNING: lat1 declared in multiple Kernels
# WARNING: u2 declared in multiple Kernels
# WARNING: v2 declared in multiple Kernels
# WARNING: lon2 declared in multiple Kernels
# WARNING: lat2 declared in multiple Kernels
# WARNING: u3 declared in multiple Kernels
# WARNING: v3 declared in multiple Kernels
# WARNING: lon3 declared in multiple Kernels
# WARNING: lat3 declared in multiple Kernels
# WARNING: u4 declared in multiple Kernels
# WARNING: v4 declared in multiple Kernels
# WARNING: u1 declared in multiple Kernels
# WARNING: v1 declared in multiple Kernels
# WARNING: lon1 declared in multiple Kernels
# WARNING: lat1 declared in multiple Kernels
# WARNING: u2 declared in multiple Kernels
# WARNING: v2 declared in multiple Kernels
# WARNING: lon2 declared in multiple Kernels
# WARNING: lat2 declared in multiple Kernels
# WARNING: u3 declared in multiple Kernels
# WARNING: v3 declared in multiple Kernels
# WARNING: lon3 declared in multiple Kernels
# WARNING: lat3 declared in multiple Kernels
# WARNING: u4 declared in multiple Kernels
# WARNING: v4 declared in multiple Kernels
# WARNING: u1 declared in multiple Kernels
# WARNING: v1 declared in multiple Kernels
# WARNING: lon1 declared in multiple Kernels
# WARNING: lat1 declared in multiple Kernels
# WARNING: u2 declared in multiple Kernels
# WARNING: v2 declared in multiple Kernels
# WARNING: lon2 declared in multiple Kernels
# WARNING: lat2 declared in multiple Kernels
# WARNING: u3 declared in multiple Kernels
# WARNING: v3 declared in multiple Kernels
# WARNING: lon3 declared in multiple Kernels
# WARNING: lat3 declared in multiple Kernels
# WARNING: u4 declared in multiple Kernels
# WARNING: v4 declared in multiple Kernels
# WARNING: Dx declared in multiple Kernels
# WARNING: Dy declared in multiple Kernels
# WARNING: Rx declared in multiple Kernels
# WARNING: Ry declared in multiple Kernels
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_12630/2472120434.py in <module>
#       1 #Run the behavioural kernels for two months
# ----> 2 IkaTest.runKernels(T=86400*10)
#
# ~/Documents/GitHubWorkspace/OFP-Ikamoana/Ikamoana/notebook/./../ikamoana/ikamoana.py in runKernels(self, T, pfile_suffix, verbose)
#     231         run_kernels = eval(KernelString[:-1])
#     232
# --> 233         self.fish.execute(
#     234             run_kernels, runtime=T, dt=self.ika_params['dt'], output_file=pfile,
#     235             recovery={
#
# ~/anaconda3/envs/cps/lib/python3.9/site-packages/parcels/particleset/baseparticleset.py in execute(self, pyfunc, pyfunc_inter, endtime, runtime, dt, moviedt, recovery, output_file, movie_background_field, verbose_progress, postIterationCallbacks, callbackdt)
#     344                 self.kernel.remove_lib()
#     345                 cppargs = ['-DDOUBLE_COORD_VARIABLES'] if self.collection.lonlatdepth_dtype else None
# --> 346                 self.kernel.compile(compiler=GNUCompiler(cppargs=cppargs, incdirs=[path.join(get_package_dir(), 'include'), "."]))
#     347                 self.kernel.load_lib()
#     348
#
# ~/anaconda3/envs/cps/lib/python3.9/site-packages/parcels/kernel/basekernel.py in compile(self, compiler)
#     248                 if self.src_file is not None:
#     249                     all_files_array.append(self.src_file)
# --> 250                 compiler.compile(self.src_file, self.lib_file, self.log_file)
#     251         if len(all_files_array) > 0:
#     252             logger.info("Compiled %s ==> %s" % (self.name, self.lib_file))
#
# ~/anaconda3/envs/cps/lib/python3.9/site-packages/parcels/compilation/codecompiler.py in compile(self, src, obj, log)
#     288         obj = os.path.join(lib_pathdir, lib_pathfile)
#     289
# --> 290         super(GNUCompiler_SS, self).compile(src, obj, log)
#     291
#     292
#
# ~/anaconda3/envs/cps/lib/python3.9/site-packages/parcels/compilation/codecompiler.py in compile(self, src, obj, log)
#     266         with open(log, 'w') as logfile:
#     267             logfile.write("Compiling: %s\n" % " ".join(cc))
# --> 268         self._create_compile_process_(cc, src, log)
#     269
#     270
#
# ~/anaconda3/envs/cps/lib/python3.9/site-packages/parcels/compilation/codecompiler.py in _create_compile_process_(self, cmd, src, log)
#     227         with open(log, 'w') as logfile:
#     228             try:
# --> 229                 subprocess.check_call(cmd, stdout=logfile, stderr=logfile)
#     230             except OSError:
#     231                 err = """OSError during compilation
#
# ~/anaconda3/envs/cps/lib/python3.9/subprocess.py in check_call(*popenargs, **kwargs)
#     366     check_call(["ls", "-l"])
#     367     """
# --> 368     retcode = call(*popenargs, **kwargs)
#     369     if retcode:
#     370         cmd = kwargs.get("args")
#
# ~/anaconda3/envs/cps/lib/python3.9/subprocess.py in call(timeout, *popenargs, **kwargs)
#     349     with Popen(*popenargs, **kwargs) as p:
#     350         try:
# --> 351             return p.wait(timeout=timeout)
#     352         except:  # Including KeyboardInterrupt, wait handled that.
#     353             p.kill()
#
# ~/anaconda3/envs/cps/lib/python3.9/subprocess.py in wait(self, timeout)
#    1187             endtime = _time() + timeout
#    1188         try:
# -> 1189             return self._wait(timeout=timeout)
#    1190         except KeyboardInterrupt:
#    1191             # https://bugs.python.org/issue25942
#
# ~/anaconda3/envs/cps/lib/python3.9/subprocess.py in _wait(self, timeout)
#    1915                         if self.returncode is not None:
#    1916                             break  # Another thread waited.
# -> 1917                         (pid, sts) = self._try_wait(0)
#    1918                         # Check the pid and loop as waitpid has been known to
#    1919                         # return 0 even without WNOHANG in odd situations.
#
# ~/anaconda3/envs/cps/lib/python3.9/subprocess.py in _try_wait(self, wait_flags)
#    1873             """All callers to this function MUST hold self._waitpid_lock."""
#    1874             try:
# -> 1875                 (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1876             except ChildProcessError:
#    1877                 # This happens if SIGCLD is set to be ignored or waiting
#
# KeyboardInterrupt:
