# %%
from sys import path
path.append("./..")
from feedingHabitat import FeedingHabitat

# %%
config_file_path = "./../Data_Test/skj_po_interim_2deg_configuration_file.xml"
feeding_habitat_1 = FeedingHabitat(config_file_path, partial_cohorts_computation=[0,11,36])

# %%
feeding_habitat_1.cohorts_to_compute
# Out:
# {0, 11, 36}

# %%
feeding_habitat_1.partial_oxygen_time_axis
# Out:
# False

# %%
feeding_habitat_1.coords
# Out:
# Coordinates:
#   * lat      (lat) float32 64.5 62.5 60.5 58.5 56.5 ... -47.5 -49.5 -51.5 -53.5
#   * lon      (lon) float32 89.5 91.5 93.5 95.5 97.5 ... 283.5 285.5 287.5 289.5
#   * time     (time) datetime64[ns] 1979-01-15T12:00:00 ... 2010-12-16T12:00:00

# %%
feeding_habitat_1.parameters_dictionary
# Out:
# {'eF_list': [3.999907116416026,
#   0.05,
#   0.897307278945509,
#   0.0,
#   0.0,
#   3.999946416753347],
#  'sigma_0': 1.492626509052,
#  'sigma_K': 3.00000257690523,
#  'T_star_1': 31.09996321152416,
#  'T_star_K': 26.04960048814059,
#  'bT': 2.83057972721579,
#  'gamma': 0.0001000000005808978,
#  'o_star': 3.764163854561827}

# %%
feeding_habitat_1.global_mask
# Out:
# {'mask_L1': array([[[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]]),
#  'mask_L2': array([[[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]]),
#  'mask_L3': array([[[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
# ...

# %%
feeding_habitat_1.variables_dictionary
# Out:
# {'oxygen_L1': array([[[0.       , 0.       , 0.       , ..., 7.9300337, 0.       ,
#           0.       ],
#          [0.       , 0.       , 0.       , ..., 7.864212 , 7.8115377,
#           7.7704916],
#          [0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#           0.       ],
#          ...,
#          [6.7561054, 6.766243 , 6.7866645, ..., 0.       , 0.       ,
#           0.       ],
#          [7.083372 , 7.06643  , 7.0589995, ..., 0.       , 0.       ,
#           0.       ],
#          [7.4327674, 7.3956604, 7.3639994, ..., 6.772896 , 0.       ,
#           0.       ]],
#
#         [[0.       , 0.       , 0.       , ..., 7.919058 , 0.       ,
#           0.       ],
#          [0.       , 0.       , 0.       , ..., 7.870743 , 7.8081126,
#           7.7761   ],
#          [0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#           0.       ],
#          ...,
#          [6.6611543, 6.675762 , 6.6965113, ..., 0.       , 0.       ,
# ...
