# %%
from sys import path
path.append("./..")
from feedingHabitat import FeedingHabitat
# Out:
# ---------------------------------------------------------------------------
# InvalidVersion                            Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pkg_resources\_vendor\packaging\version.py in parse(version)
#      55     try:
# ---> 56         return Version(version)
#      57     except InvalidVersion:
#
# ~\Anaconda3\lib\site-packages\pkg_resources\_vendor\packaging\version.py in __init__(self, version)
#     276         if not match:
# --> 277             raise InvalidVersion("Invalid version: '{0}'".format(version))
#     278
#
# InvalidVersion: Invalid version: '.egg-info'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-1c56932f8e54> in <module>
#       1 from sys import path
#       2 path.append("./..")
# ----> 3 from feedingHabitat_v2 import FeedingHabitat
#
# ...

# %%
config_file_path = "./../Data_Test/skj_po_interim_2deg_configuration_file.xml"
feeding_habitat_1 = FeedingHabitat(config_file_path, partial_cohorts_computation=[0,11,36])

# %%
feeding_habitat_1.computeFeedingHabitat('./out/')
