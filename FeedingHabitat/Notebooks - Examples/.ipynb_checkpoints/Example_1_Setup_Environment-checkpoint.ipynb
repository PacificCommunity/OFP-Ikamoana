# %% [markdown]
# # Setup Environment
# To do so, 3 additionnal libraries are needed :
#
# | &emsp;&emsp;&emsp;Library&emsp;&emsp;&emsp;  | &emsp;&emsp;Version&emsp;&emsp; |
# | :--------------------------------------------------: | :---------: |
# | [pandas](https://pandas.pydata.org/)                 | `1.2.4`     |
# | [numpy](https://numpy.org/doc/stable/index.html#)    | `1.20.3`    |
# | [netcdf4](https://unidata.github.io/netcdf4-python/) | `1.5.6`     |
# | [xarray](http://xarray.pydata.org/en/stable/)        | `0.18.2`    |
#
#
# #### **Using [Anaconda](https://www.anaconda.com/products/individual#Downloads)** : (click on link to be redirected to the Anaconda download page)
#
# The anaconda environment used in this notebook is in version `4.10.1`. To update your environment report to the `Note` section.
#
# Those libraries will need conda-forge channel.
#
# ![](./Img/anaconda_channel_1.png)
#
# Click on `Channels`.
#
# ![](./Img/anaconda_channel_2.png)
#
# Click on `Add`.
#
# ![](./Img/anaconda_channel_3.png)
#
# Write `conda-forge` then press the `enter` key.
#
# Once the last step is done, press ![](./Img/anaconda_channel_4.png) then wait until it is refresh.
#
# Go to the environments tab and select your environment (will be the `base(root)` if you didn't create another one).
#
# ![](./Img/anaconda_channel_5.png)
#
# Search for each library in the `Search Packages` tab. Make sure that you are searching in `All` packages (not only `Installed`).
#
# ![](./Img/anaconda_channel_6.png)
#
# The packages to install are shown in the following figure :
#
# ![](./Img/anaconda_channel_7.png)
#
# To install the specified versions listed in the table at the beginning, refer to the method in `Note` below.

# %% [markdown]
# #### **Note** :
#
# **Updating** your **anaconda environment** :
# - Search for conda package
#
# ![](./Img/anaconda_channel_8.png)
#
# ![](./Img/anaconda_channel_9.png)
#
# - Right-Click on green check-box
#
# ![](./Img/anaconda_channel_10.png)
#
# - Select `Mark for specific version installation` click on the `4.10.1` version.
#
# ![](./Img/anaconda_channel_11.png)

# %% [markdown]
# ---
# If the `feedingHabitat.py` file is located in another directory, you will need to add the path to that file before importing it.
# > If you are running this notebook in the same directory as the `feedingHabitat.py` file, this cell is useless.

# %%
# The path may change if you run this notebooks on your computer #
path_to_library = "./../"
# -------------------------------------------------------------- #

import sys
if path_to_library not in sys.path :
    sys.path.append(path_to_library)

# %% [markdown]
# Once it is done, import the library :

# %%
from feedingHabitat import FeedingHabitat

# %% [markdown]
# If you have no error so far then everything is ready for next steps (in others example notebooks).
#
# <br/>
#
# ---
#
# <br/>
#
# ## Note :
# If you want some help about the class and its function, python provide `help()`. This function will print the documentation of the object (class, function, etc...) passed in argument.

# %%
help(FeedingHabitat)
# Out:
# Help on class FeedingHabitat in module feedingHabitat:
#
# class FeedingHabitat(builtins.object)
#  |  FeedingHabitat(xml_filepath, partial_cohorts_computation=None, float_32=True)
#  |
#  |  Methods defined here:
#  |
#  |  __forageAtDate__(self, date, position, forage_preference_coefficients)
#  |
#  |  __forage__(self, forage_preference_coefficients)
#  |
#  |  __init__(self, xml_filepath, partial_cohorts_computation=None, float_32=True)
#  |      Initialize the FeedingHabitat instance according to the XML
#  |      configuration file passed in argument.
#  |
#  |      Parameters
#  |      ----------
#  |      xml_filepath : string
#  |          The pass to the XML configuration file.
#  |      partial_cohorts_computation : list of int, optional
#  |          If you want to perform a partial feeding habitat computation, you
#  |          can  specify a group of cohort using a number corresponding to the
#  |          position in the cohort list.
# ...
